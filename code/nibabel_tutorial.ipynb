# %%
import numpy as np
import nibabel as nib

fname = '../derivatives/fmriprep/sub-LEGK010/func/sub-LEGK010_task-rest_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'

img = nib.load(fname)
img.shape
# Out:
# (47, 58, 45, 260)

# %%
data = img.get_fdata()
data.shape
# Out:
# (47, 58, 45, 260)

# %%
hdr = img.header
print(hdr)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'')
# dim_info        : 0
# dim             : [  4  47  58  45 260   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.    3.406 3.406 3.74  2.25  1.    1.    1.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'reference image generated by GenerateSamplingReference (niworkflows v1.12.2).')
# aux_file        : np.bytes_(b'')
# ...

# %%
last_vol = img.slicer[..., -1]
last_vol.shape
# Out:
# (47, 58, 45)

# %%
# remove first 10 volumes
cropped = img.slicer[..., 10:]
cropped.shape
# Out:
# (47, 58, 45, 250)

# %%
data = np.ones((32, 32, 15, 100), dtype=np.int16)
img = nib.Nifti1Image(data, np.eye(4))

# %%
fname = '../derivatives/fmriprep/sub-LEGK010/func/sub-LEGK010_task-rest_space-fsLR_den-91k_bold.dtseries.nii'
img = nib.load(fname)
img.shape
# Out:
# (260, 91282)

# %%
img = nib.load('~/Downloads/atlas-desikankilliany-lh.label.gii.gz')
dk_atlas = img.agg_data()

# %%
dk_atlas.shape
# Out:
# (10242,)

# %%
img = nib.load('/Users/brainsimulation/Desktop/ICU Data + VNC metric files/full_hcp_preproc/derivatives/ciftify/sub-02/MNINonLinear/fsaverage_LR32k/sub-02.aparc.32k_fs_LR.dlabel.nii')
img.shape
# Out:
# (1, 59412)

# %%
from nilearn.connectome import ConnectivityMeasure
from nilearn.maskers import SurfaceLabelMasker
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 2
#       1 from nilearn.connectome import ConnectivityMeasure
# ----> 2 from nilearn.maskers import SurfaceLabelMasker
#
# ImportError: cannot import name 'SurfaceLabelMasker' from 'nilearn.maskers' (/Users/brainsimulation/Library/Python/3.9/lib/python/site-packages/nilearn/maskers/__init__.py)
